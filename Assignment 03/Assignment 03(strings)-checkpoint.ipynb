# %% [markdown]
# # String Assignment

# %% [markdown]
# ### Problem 1
# ![image.png](attachment:c2d35b17-ee86-440c-a8af-d3938039d1cf.png)

# %%
str = input("enter a string")
vowels = "aeiouAEIOU"
vowels_count = 0
for char in str:
    if char in vowels:
        vowels_count += 1
print(f" vowels count = {vowels_count}")
# Out:
# enter a string AHnsdhssjEio
#  vowels count = 4

# %% [markdown]
# ## Problem 2
# ![image.png](attachment:aac7bd2e-0c10-4ed6-8b02-fdf5483c12d4.png)

# %%
str1 = input("enter a string")
uppercase_count = 0
lowercase_count = 0
digit_count = 0
space_count = 0

for char in str1:
    if char.isupper():
        uppercase_count += 1
    elif char.islower():
        lowercase_count +=1
    elif char.isdigit():
        digit_count+=1
    elif char.isspace():
        space_count+=1


print(f" the upper case is {uppercase_count}")
print(f" the lower  case is {lowercase_count}")
print(f" the digit  is {digit_count}")
print(f" the whitespace count  is {space_count}")
# Out:
# enter a string AhdhjxEiudhjdjOusee
#  the upper case is 3
#  the lower  case is 16
#  the digit  is 0
#  the whitespace count  is 2

# %% [markdown]
# ## Problem 2
# ![image.png](attachment:aade1477-bc62-4455-9f0d-7121babdc239.png)

# %%
string = input("enter a string")
new_string = string[-1] + string[1:-1] + string[0]
print(f"the swapped string is {new_string}")
# Out:
# enter a string Hello
# the swapped string is oellH

# %% [markdown]
# ## Problem 4
# ![image.png](attachment:c043e412-bfeb-4034-bdba-fb46f82d21d0.png)

# %%
str2 = input("enter a string")
new_string = str2[::-1]
print(f"the reverse string is {new_string}")
# Out:
# enter a string EXAM
# the reverse string is MAXE

# %% [markdown]
# ## Problem 5
# ![image.png](attachment:7e811d93-36ef-4fc5-bc03-625fcc0fef45.png)

# %%
str2 = input("enter a string")
shift_str = str2[1:] + str2[0]
print(f"the shift string is {shift_str}")
# Out:
# enter a string examination 2025
# the shift string is xamination 2025e

# %% [markdown]
# ## Problem 6
# ![image.png](attachment:cde11af7-8da9-47cb-9b6c-6ab8b37e9cf2.png)

# %%
name = input("enter your name")
if name and name[0] != " ":
    print(name[0],end = ".")
i=1
while i <len(name):
    if name[i] != " " and name[i-1] == " ":
        print(name[i], end = ".")
    i +=1
# Out:
# enter your name Ahmed Ibrahim
# A.I.

# %% [markdown]
# ## Problem 7
# ![image.png](attachment:b146c1d1-9fdb-4c42-9646-102a4e8ba57d.png)

# %%
str3 = input("enter a string")
reverse_str = str3[::-1]
if str3 == reverse_str :
    print("it is palindrome")
else:
    print("it is not a palindrome")
# Out:
# enter a string madam
# it is palindrome

# %% [markdown]
# ## Problem 8
# ![image.png](attachment:5d2e8241-5bec-418f-b15c-908d891667b2.png)

# %%
str4= input("enter a string")
for i in range(len(str4)):
    shift_word = str4[i:] + str4[:i]
    print(shift_word)
# Out:
# enter a string SHIFT
# SHIFT
# HIFTS
# IFTSH
# FTSHI
# TSHIF

# %% [markdown]
# ## Problem 9
# ![image.png](attachment:e6d2c930-f0f4-443d-a0c6-e05da4b493d3.png)
# ![image.png](attachment:7fedd50c-9176-4cc4-9e29-dbe145f5bde0.png)

# %%
password = input("enter your password")

has_length = len(password) >= 8
has_upper = any(c.isupper() for c in password)
has_lower = any(c.islower() for c in password)
has_digit = any(c.isdigit() for c in password)

if has_length and has_upper and has_lower and has_digit:
    print("Valid password")
else:
    print("Invalid password")
# Out:
# enter your password Ahnehjd12345
# Valid password
